# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
name = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
record_counter = 0
set_counter = 0

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key


print('Beginning Data Retrieval')
print('------------------------')
for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))

    try:
         
        name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])

        
        
 # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)  
    
    except(KeyError):
        print(f'City not found!')
        pass
    
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | mataura
# Processing record 2 of set 0 | albany
# Processing record 3 of set 0 | greymouth
# Processing record 4 of set 0 | ushuaia
# Processing record 5 of set 0 | hofn
# Processing record 6 of set 0 | coquimbo
# Processing record 7 of set 0 | aksu
# Processing record 8 of set 0 | palabuhanratu
# City not found!
# Processing record 9 of set 0 | hobart
# Processing record 10 of set 0 | salto
# Processing record 11 of set 0 | katsuura
# Processing record 12 of set 0 | mys shmidta
# City not found!
# Processing record 13 of set 0 | coihaique
# Processing record 14 of set 0 | illoqqortoormiut
# City not found!
# Processing record 15 of set 0 | dikson
# Processing record 16 of set 0 | bandarbeyla
# Processing record 17 of set 0 | mar del plata
# Processing record 18 of set 0 | acu
# Processing record 19 of set 0 | port macquarie
# Processing record 20 of set 0 | nisia floresta
# Processing record 21 of set 0 | bethel
# Processing record 22 of set 0 | punta arenas
# Processing record 23 of set 0 | lubango
# Processing record 24 of set 0 | hithadhoo
# Processing record 25 of set 0 | batemans bay
# Processing record 26 of set 0 | nikolskoye
# Processing record 27 of set 0 | upernavik
# Processing record 28 of set 0 | marawi
# Processing record 29 of set 0 | thompson
# Processing record 30 of set 0 | clonakilty
# Processing record 31 of set 0 | east london
# Processing record 32 of set 0 | castro
# Processing record 33 of set 0 | pilar
# Processing record 34 of set 0 | grindavik
# Processing record 35 of set 0 | el alto
# Processing record 36 of set 0 | ust-kamchatsk
# City not found!
# Processing record 37 of set 0 | jumla
# Processing record 38 of set 0 | puerto ayora
# Processing record 39 of set 0 | campina verde
# Processing record 40 of set 0 | katherine
# Processing record 41 of set 0 | kuytun
# Processing record 42 of set 0 | galgani
# City not found!
# Processing record 43 of set 0 | cape town
# Processing record 44 of set 0 | tasiilaq
# Processing record 45 of set 0 | vaitupu
# City not found!
# Processing record 46 of set 0 | ewo
# Processing record 47 of set 0 | airai
# Processing record 48 of set 0 | sorland
# Processing record 49 of set 0 | atlantic beach
# Processing record 50 of set 0 | pacific grove
# Processing record 0 of set 1 | aykhal
# Processing record 1 of set 1 | alofi
# Processing record 2 of set 1 | nanga eboko
# Processing record 3 of set 1 | kisangani
# Processing record 4 of set 1 | provideniya
# Processing record 5 of set 1 | saint-philippe
# Processing record 6 of set 1 | taolanaro
# City not found!
# Processing record 7 of set 1 | saldanha
# Processing record 8 of set 1 | kruisfontein
# Processing record 9 of set 1 | natori
# Processing record 10 of set 1 | hauterive
# Processing record 11 of set 1 | thongwa
# Processing record 12 of set 1 | anthia
# City not found!
# Processing record 13 of set 1 | victoria
# Processing record 14 of set 1 | bull savanna
# Processing record 15 of set 1 | chegem
# Processing record 16 of set 1 | whitehorse
# Processing record 17 of set 1 | polunochnoye
# Processing record 18 of set 1 | sinnamary
# Processing record 19 of set 1 | bredasdorp
# Processing record 20 of set 1 | ekhabi
# Processing record 21 of set 1 | sao filipe
# Processing record 22 of set 1 | arraial do cabo
# Processing record 23 of set 1 | maniitsoq
# Processing record 24 of set 1 | edson
# Processing record 25 of set 1 | chokwe
# Processing record 26 of set 1 | lagoa
# Processing record 27 of set 1 | saleaula
# City not found!
# Processing record 28 of set 1 | trinidad
# Processing record 29 of set 1 | porto san giorgio
# Processing record 30 of set 1 | rikitea
# Processing record 31 of set 1 | port alfred
# Processing record 32 of set 1 | kamenskoye
# City not found!
# Processing record 33 of set 1 | balabac
# Processing record 34 of set 1 | potosi
# Processing record 35 of set 1 | tecoanapa
# Processing record 36 of set 1 | dalaba
# Processing record 37 of set 1 | tilichiki
# Processing record 38 of set 1 | constitucion
# Processing record 39 of set 1 | evanston
# Processing record 40 of set 1 | ilulissat
# Processing record 41 of set 1 | vieques
# Processing record 42 of set 1 | evensk
# Processing record 43 of set 1 | chapais
# Processing record 44 of set 1 | hilo
# Processing record 45 of set 1 | atambua
# Processing record 46 of set 1 | nha trang
# Processing record 47 of set 1 | abu samrah
# Processing record 48 of set 1 | qaanaaq
# Processing record 49 of set 1 | cabo san lucas
# Processing record 50 of set 1 | chokurdakh
# Processing record 0 of set 2 | longyearbyen
# Processing record 1 of set 2 | vardo
# Processing record 2 of set 2 | dingle
# Processing record 3 of set 2 | busselton
# Processing record 4 of set 2 | georgetown
# Processing record 5 of set 2 | vaini
# Processing record 6 of set 2 | saint george
# Processing record 7 of set 2 | salalah
# Processing record 8 of set 2 | jamestown
# Processing record 9 of set 2 | vila velha
# Processing record 10 of set 2 | inhambane
# Processing record 11 of set 2 | po
# City not found!
# Processing record 12 of set 2 | dudinka
# Processing record 13 of set 2 | darhan
# Processing record 14 of set 2 | alexandria
# Processing record 15 of set 2 | krasnoselkup
# Processing record 16 of set 2 | bluff
# Processing record 17 of set 2 | lugovoy
# Processing record 18 of set 2 | kapaa
# Processing record 19 of set 2 | barentsburg
# City not found!
# Processing record 20 of set 2 | ribeira grande
# Processing record 21 of set 2 | atuona
# Processing record 22 of set 2 | yellowknife
# Processing record 23 of set 2 | mayumba
# Processing record 24 of set 2 | menongue
# Processing record 25 of set 2 | new norfolk
# Processing record 26 of set 2 | college
# Processing record 27 of set 2 | waipawa
# Processing record 28 of set 2 | severnyy
# Processing record 29 of set 2 | olafsvik
# Processing record 30 of set 2 | butaritari
# Processing record 31 of set 2 | calbuco
# Processing record 32 of set 2 | esperance
# Processing record 33 of set 2 | torbay
# Processing record 34 of set 2 | belaya gora
# Processing record 35 of set 2 | haimen
# Processing record 36 of set 2 | wuda
# Processing record 37 of set 2 | razlog
# Processing record 38 of set 2 | malanje
# Processing record 39 of set 2 | barrow
# Processing record 40 of set 2 | san francisco del mar
# Processing record 41 of set 2 | pandamatenga
# Processing record 42 of set 2 | banepa
# Processing record 43 of set 2 | amderma
# City not found!
# Processing record 44 of set 2 | linxia
# Processing record 45 of set 2 | tautira
# Processing record 46 of set 2 | denpasar
# Processing record 47 of set 2 | port blair
# Processing record 48 of set 2 | anloga
# Processing record 49 of set 2 | longonjo
# Processing record 50 of set 2 | gashua
# Processing record 0 of set 3 | hermanus
# Processing record 1 of set 3 | seydi
# Processing record 2 of set 3 | pali
# Processing record 3 of set 3 | san patricio
# Processing record 4 of set 3 | maghama
# City not found!
# Processing record 5 of set 3 | faanui
# Processing record 6 of set 3 | kilinochchi
# Processing record 7 of set 3 | port elizabeth
# Processing record 8 of set 3 | marsh harbour
# Processing record 9 of set 3 | limbe
# Processing record 10 of set 3 | lebu
# Processing record 11 of set 3 | thinadhoo
# Processing record 12 of set 3 | sahy
# Processing record 13 of set 3 | lolua
# City not found!
# Processing record 14 of set 3 | naze
# Processing record 15 of set 3 | port hedland
# Processing record 16 of set 3 | tulun
# Processing record 17 of set 3 | mount isa
# Processing record 18 of set 3 | san quintin
# Processing record 19 of set 3 | aktas
# Processing record 20 of set 3 | saskylakh
# Processing record 21 of set 3 | doraha
# Processing record 22 of set 3 | souillac
# Processing record 23 of set 3 | floro
# Processing record 24 of set 3 | alibag
# Processing record 25 of set 3 | beisfjord
# Processing record 26 of set 3 | cidreira
# Processing record 27 of set 3 | bilibino
# Processing record 28 of set 3 | ponta do sol
# Processing record 29 of set 3 | ghorawal
# Processing record 30 of set 3 | puerto del rosario
# Processing record 31 of set 3 | flinders
# Processing record 32 of set 3 | bambous virieux
# Processing record 33 of set 3 | urulga
# City not found!
# Processing record 34 of set 3 | nuuk
# Processing record 35 of set 3 | san cristobal
# Processing record 36 of set 3 | avarua
# Processing record 37 of set 3 | belushya guba
# City not found!
# Processing record 38 of set 3 | huarmey
# Processing record 39 of set 3 | vila franca do campo
# Processing record 40 of set 3 | hasaki
# Processing record 41 of set 3 | iqaluit
# Processing record 42 of set 3 | codrington
# Processing record 43 of set 3 | hay river
# Processing record 44 of set 3 | ipixuna
# Processing record 45 of set 3 | kavaratti
# Processing record 46 of set 3 | yar-sale
# Processing record 47 of set 3 | temaraia
# City not found!
# Processing record 48 of set 3 | tsihombe
# City not found!
# Processing record 49 of set 3 | port lincoln
# Processing record 50 of set 3 | solnechnyy
# Processing record 0 of set 4 | daxian
# City not found!
# Processing record 1 of set 4 | barranca
# Processing record 2 of set 4 | taltal
# Processing record 3 of set 4 | khatanga
# Processing record 4 of set 4 | vallenar
# Processing record 5 of set 4 | tuktoyaktuk
# Processing record 6 of set 4 | aksha
# Processing record 7 of set 4 | gasa
# Processing record 8 of set 4 | guiglo
# Processing record 9 of set 4 | san felipe
# Processing record 10 of set 4 | los llanos de aridane
# Processing record 11 of set 4 | ridgecrest
# Processing record 12 of set 4 | terrace
# Processing record 13 of set 4 | ta khmau
# Processing record 14 of set 4 | alice springs
# Processing record 15 of set 4 | talnakh
# Processing record 16 of set 4 | laguna
# Processing record 17 of set 4 | burica
# City not found!
# Processing record 18 of set 4 | nara
# Processing record 19 of set 4 | carnarvon
# Processing record 20 of set 4 | quyquyho
# City not found!
# Processing record 21 of set 4 | nagar karnul
# Processing record 22 of set 4 | khani
# Processing record 23 of set 4 | weligama
# Processing record 24 of set 4 | kaitangata
# Processing record 25 of set 4 | road town
# Processing record 26 of set 4 | apatin
# Processing record 27 of set 4 | oranjemund
# Processing record 28 of set 4 | kimbe
# Processing record 29 of set 4 | phan rang
# City not found!
# Processing record 30 of set 4 | ulladulla
# Processing record 31 of set 4 | kodiak
# Processing record 32 of set 4 | tumannyy
# City not found!
# Processing record 33 of set 4 | lazaro cardenas
# Processing record 34 of set 4 | mahebourg
# Processing record 35 of set 4 | salamiyah
# Processing record 36 of set 4 | chom bung
# City not found!
# Processing record 37 of set 4 | rizoma
# Processing record 38 of set 4 | grand gaube
# Processing record 39 of set 4 | linguere
# Processing record 40 of set 4 | balkhash
# Processing record 41 of set 4 | esil
# Processing record 42 of set 4 | nanortalik
# Processing record 43 of set 4 | bengkulu
# Processing record 44 of set 4 | vao
# Processing record 45 of set 4 | chupa
# Processing record 46 of set 4 | tromso
# Processing record 47 of set 4 | grenada
# Processing record 48 of set 4 | narsaq
# Processing record 49 of set 4 | hovd
# Processing record 50 of set 4 | llata
# Processing record 0 of set 5 | vestmanna
# Processing record 1 of set 5 | inuvik
# Processing record 2 of set 5 | kavieng
# Processing record 3 of set 5 | shenjiamen
# Processing record 4 of set 5 | sitka
# Processing record 5 of set 5 | makat
# Processing record 6 of set 5 | londoko
# Processing record 7 of set 5 | omboue
# Processing record 8 of set 5 | camacha
# Processing record 9 of set 5 | srednekolymsk
# Processing record 10 of set 5 | banda aceh
# Processing record 11 of set 5 | noumea
# Processing record 12 of set 5 | aklavik
# Processing record 13 of set 5 | ancud
# Processing record 14 of set 5 | comodoro rivadavia
# Processing record 15 of set 5 | lasa
# Processing record 16 of set 5 | haines junction
# Processing record 17 of set 5 | lokosovo
# Processing record 18 of set 5 | berlevag
# Processing record 19 of set 5 | roald
# Processing record 20 of set 5 | te anau
# Processing record 21 of set 5 | nichinan
# Processing record 22 of set 5 | the valley
# Processing record 23 of set 5 | nador
# Processing record 24 of set 5 | bonavista
# Processing record 25 of set 5 | kuntaur
# Processing record 26 of set 5 | shanghai
# Processing record 27 of set 5 | matara
# Processing record 28 of set 5 | tsurugi
# Processing record 29 of set 5 | zhigansk
# Processing record 30 of set 5 | namatanai
# Processing record 31 of set 5 | vostok
# Processing record 32 of set 5 | abha
# Processing record 33 of set 5 | soyo
# Processing record 34 of set 5 | port hardy
# Processing record 35 of set 5 | koutsouras
# Processing record 36 of set 5 | turukhansk
# Processing record 37 of set 5 | pitsunda
# Processing record 38 of set 5 | vuktyl
# Processing record 39 of set 5 | fare
# Processing record 40 of set 5 | kenora
# Processing record 41 of set 5 | taunggyi
# Processing record 42 of set 5 | malartic
# Processing record 43 of set 5 | chuy
# Processing record 44 of set 5 | betsiamites
# Processing record 45 of set 5 | pevek
# Processing record 46 of set 5 | atlantic city
# Processing record 47 of set 5 | chalmette
# Processing record 48 of set 5 | tazovskiy
# Processing record 49 of set 5 | petropavlovsk-kamchatskiy
# Processing record 50 of set 5 | luderitz
# Processing record 0 of set 6 | isangel
# Processing record 1 of set 6 | abu dhabi
# Processing record 2 of set 6 | marsa matruh
# Processing record 3 of set 6 | talaya
# Processing record 4 of set 6 | padang
# Processing record 5 of set 6 | wajir
# Processing record 6 of set 6 | havelock
# Processing record 7 of set 6 | carauari
# Processing record 8 of set 6 | grand river south east
# City not found!
# Processing record 9 of set 6 | ostrov
# Processing record 10 of set 6 | saint-leu
# Processing record 11 of set 6 | achisay
# City not found!
# Processing record 12 of set 6 | parabel
# Processing record 13 of set 6 | sangar
# Processing record 14 of set 6 | yairipok
# Processing record 15 of set 6 | kaohsiung
# Processing record 16 of set 6 | torit
# Processing record 17 of set 6 | cayenne
# Processing record 18 of set 6 | armacao dos buzios
# City not found!
# Processing record 19 of set 6 | chimbote
# Processing record 20 of set 6 | guiratinga
# Processing record 21 of set 6 | fortuna
# Processing record 22 of set 6 | kloulklubed
# Processing record 23 of set 6 | lorengau
# Processing record 24 of set 6 | saryshagan
# City not found!
# Processing record 25 of set 6 | draguignan
# Processing record 26 of set 6 | samusu
# City not found!
# Processing record 27 of set 6 | ternate
# Processing record 28 of set 6 | umm durman
# City not found!
# Processing record 29 of set 6 | rundu
# Processing record 30 of set 6 | ossora
# Processing record 31 of set 6 | fairfield
# Processing record 32 of set 6 | mareeba
# Processing record 33 of set 6 | aswan
# Processing record 34 of set 6 | sergeyevka
# Processing record 35 of set 6 | mount gambier
# Processing record 36 of set 6 | cockburn town
# Processing record 37 of set 6 | ullapool
# Processing record 38 of set 6 | boa vista
# Processing record 39 of set 6 | gat
# Processing record 40 of set 6 | nizhneyansk
# City not found!
# Processing record 41 of set 6 | vuyyuru
# Processing record 42 of set 6 | padilla
# Processing record 43 of set 6 | eregli
# Processing record 44 of set 6 | devils lake
# Processing record 45 of set 6 | champerico
# Processing record 46 of set 6 | bababe
# City not found!
# Processing record 47 of set 6 | alghero
# Processing record 48 of set 6 | nuevo progreso
# Processing record 49 of set 6 | kodinsk
# Processing record 50 of set 6 | tara
# Processing record 0 of set 7 | bintulu
# Processing record 1 of set 7 | harper
# Processing record 2 of set 7 | mount barker
# Processing record 3 of set 7 | cherskiy
# Processing record 4 of set 7 | iquique
# Processing record 5 of set 7 | poronaysk
# Processing record 6 of set 7 | berdigestyakh
# Processing record 7 of set 7 | sahrak
# City not found!
# Processing record 8 of set 7 | batticaloa
# Processing record 9 of set 7 | rio grande
# Processing record 10 of set 7 | westport
# Processing record 11 of set 7 | qarqin
# Processing record 12 of set 7 | ahuimanu
# Processing record 13 of set 7 | asau
# Processing record 14 of set 7 | charagua
# Processing record 15 of set 7 | yanan
# City not found!
# Processing record 16 of set 7 | coaraci
# Processing record 17 of set 7 | chicama
# Processing record 18 of set 7 | talwandi bhai
# Processing record 19 of set 7 | independence
# Processing record 20 of set 7 | meyungs
# City not found!
# Processing record 21 of set 7 | borogontsy
# Processing record 22 of set 7 | naryan-mar
# Processing record 23 of set 7 | inta
# Processing record 24 of set 7 | vanavara
# Processing record 25 of set 7 | pisco
# Processing record 26 of set 7 | husavik
# Processing record 27 of set 7 | lavrentiya
# Processing record 28 of set 7 | deshna
# City not found!
# Processing record 29 of set 7 | novaya ladoga
# Processing record 30 of set 7 | gulshat
# City not found!
# Processing record 31 of set 7 | katobu
# Processing record 32 of set 7 | honggang
# Processing record 33 of set 7 | sakaiminato
# Processing record 34 of set 7 | moramanga
# Processing record 35 of set 7 | iberia
# Processing record 36 of set 7 | avera
# Processing record 37 of set 7 | sisimiut
# Processing record 38 of set 7 | huilong
# Processing record 39 of set 7 | maraa
# Processing record 40 of set 7 | touros
# Processing record 41 of set 7 | krosno odrzanskie
# Processing record 42 of set 7 | hobyo
# Processing record 43 of set 7 | khandbari
# Processing record 44 of set 7 | severo-kurilsk
# Processing record 45 of set 7 | palana
# Processing record 46 of set 7 | peleduy
# Processing record 47 of set 7 | gympie
# Processing record 48 of set 7 | doha
# Processing record 49 of set 7 | tocopilla
# Processing record 50 of set 7 | paka
# Processing record 0 of set 8 | pokhara
# Processing record 1 of set 8 | bay roberts
# Processing record 2 of set 8 | kirakira
# Processing record 3 of set 8 | dianopolis
# City not found!
# Processing record 4 of set 8 | norman wells
# Processing record 5 of set 8 | lucapa
# Processing record 6 of set 8 | klaksvik
# Processing record 7 of set 8 | matamoros
# Processing record 8 of set 8 | birjand
# Processing record 9 of set 8 | chany
# Processing record 10 of set 8 | zhezkazgan
# Processing record 11 of set 8 | tarakan
# Processing record 12 of set 8 | nome
# Processing record 13 of set 8 | takaka
# Processing record 14 of set 8 | leningradskiy
# Processing record 15 of set 8 | sentyabrskiy
# City not found!
# Processing record 16 of set 8 | tateyama
# Processing record 17 of set 8 | praia
# Processing record 18 of set 8 | kitob
# Processing record 19 of set 8 | zeya
# Processing record 20 of set 8 | kununurra
# Processing record 21 of set 8 | charters towers
# Processing record 22 of set 8 | gbarnga
# Processing record 23 of set 8 | tabuk
# Processing record 24 of set 8 | broome
# Processing record 25 of set 8 | birsk
# Processing record 26 of set 8 | khuzdar
# Processing record 27 of set 8 | kriel
# Processing record 28 of set 8 | tambacounda
# Processing record 29 of set 8 | dubbo
# Processing record 30 of set 8 | moron
# Processing record 31 of set 8 | kharsia
# Processing record 32 of set 8 | muros
# Processing record 33 of set 8 | shingu
# Processing record 34 of set 8 | dinguiraye
# Processing record 35 of set 8 | ust-tsilma
# Processing record 36 of set 8 | adrar
# Processing record 37 of set 8 | biltine
# Processing record 38 of set 8 | sobolevo
# Processing record 39 of set 8 | llanes
# Processing record 40 of set 8 | bonthe
# Processing record 41 of set 8 | paciran
# Processing record 42 of set 8 | valparaiso
# Processing record 43 of set 8 | plomarion
# Processing record 44 of set 8 | dongsheng
# Processing record 45 of set 8 | betanzos
# Processing record 46 of set 8 | jam sahib
# Processing record 47 of set 8 | balkanabat
# Processing record 48 of set 8 | brainerd
# Processing record 49 of set 8 | rio gallegos
# Processing record 50 of set 8 | cartagena del chaira
# Processing record 0 of set 9 | monywa
# Processing record 1 of set 9 | aljezur
# Processing record 2 of set 9 | roma
# Processing record 3 of set 9 | irtyshskiy
# Processing record 4 of set 9 | daru
# Processing record 5 of set 9 | casillas
# Processing record 6 of set 9 | saint-francois
# Processing record 7 of set 9 | san vicente
# Processing record 8 of set 9 | barreirinha
# Processing record 9 of set 9 | ostrovnoy
# Processing record 10 of set 9 | zhangjiakou
# Processing record 11 of set 9 | balimo
# City not found!
# Processing record 12 of set 9 | malakal
# Processing record 13 of set 9 | kautokeino
# Processing record 14 of set 9 | kuche
# City not found!
# Processing record 15 of set 9 | plettenberg bay
# Processing record 16 of set 9 | quatre cocos
# Processing record 17 of set 9 | nemuro
# Processing record 18 of set 9 | mingshui
# Processing record 19 of set 9 | wundanyi
# Processing record 20 of set 9 | perelyub
# Processing record 21 of set 9 | anahuac
# Processing record 22 of set 9 | dumka
# Processing record 23 of set 9 | svetlogorsk
# Processing record 24 of set 9 | pemangkat
# Processing record 25 of set 9 | mentok
# City not found!
# Processing record 26 of set 9 | biak
# Processing record 27 of set 9 | nevers
# Processing record 28 of set 9 | kontagora
# Processing record 29 of set 9 | ati
# Processing record 30 of set 9 | staraya poltavka
# Processing record 31 of set 9 | yablonovo
# Processing record 32 of set 9 | alaca
# Processing record 33 of set 9 | itambacuri
# Processing record 34 of set 9 | gamba
# Processing record 35 of set 9 | zarechnyy
# Processing record 36 of set 9 | horodyshche
# Processing record 37 of set 9 | iracoubo
# Processing record 38 of set 9 | half moon bay
# Processing record 39 of set 9 | verkhnyaya inta
# Processing record 40 of set 9 | fatehpur
# Processing record 41 of set 9 | jablah
# Processing record 42 of set 9 | maues
# Processing record 43 of set 9 | amahai
# Processing record 44 of set 9 | amarillo
# Processing record 45 of set 9 | diego de almagro
# Processing record 46 of set 9 | salta
# Processing record 47 of set 9 | lengerich
# Processing record 48 of set 9 | antsohihy
# Processing record 49 of set 9 | gerash
# Processing record 50 of set 9 | sarny
# Processing record 0 of set 10 | santa maria
# Processing record 1 of set 10 | tucupita
# Processing record 2 of set 10 | urdoma
# Processing record 3 of set 10 | oga
# Processing record 4 of set 10 | muddebihal
# Processing record 5 of set 10 | chemin grenier
# Processing record 6 of set 10 | novyy urengoy
# Processing record 7 of set 10 | kostolac
# Processing record 8 of set 10 | perth
# Processing record 9 of set 10 | haapiti
# Processing record 10 of set 10 | korla
# Processing record 11 of set 10 | mahibadhoo
# Processing record 12 of set 10 | ozernovskiy
# Processing record 13 of set 10 | solwezi
# Processing record 14 of set 10 | brae
# Processing record 15 of set 10 | margate
# Processing record 16 of set 10 | cape coast
# Processing record 17 of set 10 | durban
# Processing record 18 of set 10 | mulchen
# Processing record 19 of set 10 | ahipara
# Processing record 20 of set 10 | parana
# Processing record 21 of set 10 | vagur
# Processing record 22 of set 10 | rudnyy
# Processing record 23 of set 10 | bolshoy kamen
# Processing record 24 of set 10 | kupang
# Processing record 25 of set 10 | gushikawa
# Processing record 26 of set 10 | takoradi
# Processing record 27 of set 10 | monki
# Processing record 28 of set 10 | lubbock
# Processing record 29 of set 10 | namibe
# Processing record 30 of set 10 | fairbanks
# Processing record 31 of set 10 | awassa
# Processing record 32 of set 10 | pokrovsk
# Processing record 33 of set 10 | okhotsk
# Processing record 34 of set 10 | olbia
# Processing record 35 of set 10 | itoman
# Processing record 36 of set 10 | ketchikan
# Processing record 37 of set 10 | toliary
# City not found!
# Processing record 38 of set 10 | komsomolskiy
# Processing record 39 of set 10 | zaragoza
# Processing record 40 of set 10 | mouzakion
# City not found!
# Processing record 41 of set 10 | ambilobe
# Processing record 42 of set 10 | warri
# Processing record 43 of set 10 | zapolyarnyy
# Processing record 44 of set 10 | aitape
# Processing record 45 of set 10 | zaraza
# Processing record 46 of set 10 | lompoc
# Processing record 47 of set 10 | elbistan
# Processing record 48 of set 10 | vilhena
# Processing record 49 of set 10 | tahta
# Processing record 50 of set 10 | lata
# Processing record 0 of set 11 | ishim
# Processing record 1 of set 11 | songjianghe
# Processing record 2 of set 11 | tarudant
# City not found!
# Processing record 3 of set 11 | tiksi
# Processing record 4 of set 11 | natal
# Processing record 5 of set 11 | fontem
# Processing record 6 of set 11 | camacupa
# Processing record 7 of set 11 | totness
# Processing record 8 of set 11 | paamiut
# Processing record 9 of set 11 | moiyabana
# City not found!
# Processing record 10 of set 11 | sao jose da coroa grande
# Processing record 11 of set 11 | muisne
# Processing record 12 of set 11 | acajutla
# Processing record 13 of set 11 | chernyshevskiy
# Processing record 14 of set 11 | karratha
# Processing record 15 of set 11 | mallama
# City not found!
# Processing record 16 of set 11 | salon
# Processing record 17 of set 11 | bambanglipuro
# Processing record 18 of set 11 | siocon
# Processing record 19 of set 11 | najran
# Processing record 20 of set 11 | nombre de dios
# Processing record 21 of set 11 | yulara
# Processing record 22 of set 11 | imbituba
# Processing record 23 of set 11 | eureka
# Processing record 24 of set 11 | qaqortoq
# Processing record 25 of set 11 | plouzane
# Processing record 26 of set 11 | diffa
# Processing record 27 of set 11 | arman
# Processing record 28 of set 11 | guamal
# Processing record 29 of set 11 | one hundred mile house
# City not found!
# Processing record 30 of set 11 | voloshka
# Processing record 31 of set 11 | sayyan
# Processing record 32 of set 11 | senno
# Processing record 33 of set 11 | nguiu
# City not found!
# Processing record 34 of set 11 | luganville
# Processing record 35 of set 11 | cabedelo
# Processing record 36 of set 11 | auki
# Processing record 37 of set 11 | kholm
# Processing record 38 of set 11 | north vanlaiphai
# Processing record 39 of set 11 | comrat
# Processing record 40 of set 11 | dujuma
# City not found!
# Processing record 41 of set 11 | cururupu
# Processing record 42 of set 11 | colonia
# Processing record 43 of set 11 | hamilton
# Processing record 44 of set 11 | gubkinskiy
# Processing record 45 of set 11 | zyryanka
# Processing record 46 of set 11 | port-gentil
# Processing record 47 of set 11 | nacala
# Processing record 48 of set 11 | havre-saint-pierre
# Processing record 49 of set 11 | labuhan
# Processing record 50 of set 11 | lopukhiv
# Processing record 0 of set 12 | puerto escondido
# Processing record 1 of set 12 | raudeberg
# Processing record 2 of set 12 | saumur
# Processing record 3 of set 12 | son tay
# Processing record 4 of set 12 | san joaquin
# Processing record 5 of set 12 | aflu
# City not found!
# Processing record 6 of set 12 | mildura
# Processing record 7 of set 12 | kegayli
# City not found!
# Processing record 8 of set 12 | esso
# Processing record 9 of set 12 | umzimvubu
# City not found!
# Processing record 10 of set 12 | tonaya
# Processing record 11 of set 12 | samarai
# Processing record 12 of set 12 | kangaatsiaq
# Processing record 13 of set 12 | labrea
# Processing record 14 of set 12 | sistranda
# Processing record 15 of set 12 | butajira
# Processing record 16 of set 12 | maldonado
# Processing record 17 of set 12 | deputatskiy
# Processing record 18 of set 12 | copiapo
# Processing record 19 of set 12 | portland
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherpy_dict = {
    "City":name,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp":temp,
    "Humidity":humidity,
    "Cloudiness":cloudiness,
    "Wind Speed":wind,
    "Country":country,
    "Date":date    
}

weather_data_df = pd.DataFrame(weatherpy_dict)
weather_data_df.head()

weather_data_df.to_csv("../WeatherPy/cities.csv")

# %%
weather_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Mataura -46.1927  168.8643     43.56        92          35        2.08
# 1     Albany  42.6001  -73.9662     30.99        72         100        3.00
# 2  Greymouth -42.4667  171.2000     56.61        88          13        6.11
# 3    Ushuaia -54.8000  -68.3000     53.60        50          40       26.46
# 4       Hofn  64.2539  -15.2082     33.80        64          75       11.50
#
#   Country        Date
# 0      NZ  1612367363
# 1      US  1612367286
# 2      NZ  1612367365
# 3      AR  1612367367
# 4      IS  1612367368

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_test = weather_data_df["Humidity"].describe(include = "all")
humidity_test
# Out:
# count    577.000000
# mean      71.616984
# std       20.145924
# min        8.000000
# 25%       62.000000
# 50%       76.000000
# 75%       87.000000
# max      100.000000
# Name: Humidity, dtype: float64

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
weather_data_df.plot(kind='scatter', x='Lat', y='Max Temp', c='SteelBlue', edgecolor = "black")
plt.title('City Latitude Vs Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("../WeatherPy/LatitudeVsTemperature.png")

# %%
The highest temperatures are found at 0 latitude. As latidude increases the temperature drops.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
weather_data_df.plot(kind='scatter',x='Lat',y='Humidity', c='SteelBlue', edgecolor = "black")
plt.title('City Latitude Vs Max Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("../WeatherPy/LatitudeVsHumidity.png")

# %%
As latitude incleases,humidity increases in southern hemisphere.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
weather_data_df.plot(kind='scatter',x='Lat',y='Cloudiness', c='SteelBlue', edgecolor = "black")
plt.title('City Latitude Vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig("../WeatherPy/LatitudeVsCloudiness.png")

# %%
Cloudiness data varies greatly across the latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
weather_data_df.plot(kind='scatter',x='Lat',y='Wind Speed', c='SteelBlue', edgecolor = "black")
plt.title('City Latitude Vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig("../WeatherPy/LatitudeVsWindSpeed.png")

# %%
Wind speed data varies greatly across the latitude.

# %% [markdown]
# ## Linear Regression

# %%
northern_hemisphere = weather_data_df.loc[weather_data_df["Lat"] >= 0]
southern_hemisphere = weather_data_df.loc[weather_data_df["Lat"] < 0]


def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])
annotate(equation, 0, 0)

plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../WeatherPy/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.87

# %%
There is a strong negative correlation between latitude and max temperature in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
equation = linear_regression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])
annotate(equation, -30, 50)

plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../WeatherPy/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.61

# %%
There is a positive correlation between latitude and max temperature in the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])
annotate(equation, 40, 15)

plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../WeatherPy/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.47

# %%
There is a positive correlation between latitude and humidity in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])
annotate(equation, -40, 50)

plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../WeatherPy/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.09

# %%
There is a minimal positive correlation between latitude and humidity in the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])
annotate(equation, 30, 40)

plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../WeatherPy/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.32

# %%
There is a positive correlation between latitude and cloudiness in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])
annotate(equation, -30, 40)

plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../WeatherPy/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.28

# %%
There is a positive correlation between latitude and cloudiness in the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])
annotate(equation, 40, 20)

plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../WeatherPy/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.08

# %%
There is a slight positive correlation between latitude and windspeed in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])
annotate(equation, -30, 15)

plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../WeatherPy/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.06

# %%
There is a slight negative correlation between latitude and wind speed in the southern hemisphere.
